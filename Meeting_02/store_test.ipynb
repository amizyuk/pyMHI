# %% [markdown]
# ## notebook to notebook data tunnelling :)

# %%
# %store -r z

# %%
z?

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# z          ndarray    100x100: 10000 elems, type `float64`, 80000 bytes

# %%
# %who ndarray
# Out:
# z

# %%
z.shape
# Out:
# (100, 100)

# %%
z[50,50]
# Out:
# 0.063423919656564923

# %%
pcolor(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bb6ed585092c> in <module>()
# ----> 1 pcolor(z)
#
# NameError: name 'pcolor' is not defined

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pcolor(z)

# %%
newz = z

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# newz       ndarray    100x100: 10000 elems, type `float64`, 80000 bytes
# z          ndarray    100x100: 10000 elems, type `float64`, 80000 bytes

# %%
newz[:,50] +=0.1

# %%
pcolor(newz)

# %%
pcolor(z)

# %% [markdown]
# ### Но мы не меняли z!!! Как же так?!

# %%
pcolor(z)

# %%
newz = z.copy()

# %% [markdown]
# ### Важно: для создания нового массива используем copy()

# %%
newz[:,25] +=0.1

# %%
pcolor(newz)

# %%
pcolor(z)

# %% [markdown]
# z это не список!!!

# %%
subplot(211)
contourf(z)
colorbar()
subplot(212)
contourf(z*0.5)
colorbar()

# %%
subplot(211)
contourf(z)
colorbar()
subplot(212)
contourf(z.T)
colorbar()

# %% [markdown]
# размерность это картеж

# %%
z.shape
# Out:
# (100, 100)

# %%
z.shape = (50,200)

# %%
pcolor(z)

# %%
subplot(211)
pcolor(flipud(z))
subplot(212)
pcolor(fliplr(z.T))

# %%
z.shape
# Out:
# (50, 200)

# %%
subplot(211)
pcolor(diff(z,axis=1))
colorbar()
subplot(212)
pcolor(diff(z,axis=0))
colorbar()

# %%
fig = figure()
subplot(211)
pcolor(np.diff(z,axis=1))
colorbar()
subplot(212)
pcolor(np.diff(z,axis=0))
colorbar()

# %%
fig.savefig('out.png',dpi=300)

# %%
ls
# Out:
# Lesson_02_pylab_magic.ipynb  out.png  store_test.ipynb

# %%
# !ristretto out.png

# %% [markdown]
# ### Итерация в лоб! Всё есть объект... куски массива тоже объекты, по ним тоже можно итерировать

# %%
z.shape
# Out:
# (50, 200)

# %%
for line in z:
    print(line.shape)
# Out:
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)
# (200,)

# %%
fig = figure(figsize=(10,8))
for line in z:
    plot(line)

# %%
type(line)
# Out:
# numpy.ndarray

# %%
x = linspace(0,2*pi,200)

# %%
plot(x,line)
plot(x,rand(200)-1)

# %%
line += 0.5*(rand(200)-0.5)

# %%
plot(x,line)
